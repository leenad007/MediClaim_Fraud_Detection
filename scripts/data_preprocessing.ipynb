# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Data Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
 
# Machine Learning Models
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

# Model Evaluation
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

from sklearn.metrics import classification_report, accuracy_score
import random
random.seed(100)

# %%
# Specify the path to your CSV file
file_path = 'D:/Naira Documents/Git_projects/MediClaim_Fraud_Detection/Data/training_data.csv'

# Load the CSV data into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(df.head())
# Out:
#    Unnamed: 0     BeneID   ClaimID  Provider  InscClaimAmtReimbursed  \
# 0           0  BENE11001  CLM46614  PRV55912                   26000
# 1           1  BENE11001  CLM66048  PRV55907                    5000
# 2           2  BENE11001  CLM68358  PRV56046                    5000
# 3           3  BENE11011  CLM38412  PRV52405                    5000
# 4           4  BENE11014  CLM63689  PRV56614                   10000
#
#    DeductibleAmtPaid  ClaimPeriod  TimeInHptal  Diagnosis Count  \
# 0             1068.0            6            6              9.0
# 1             1068.0            2            2              3.0
# 2             1068.0            3            3              6.0
# 3             1068.0            8            8              9.0
# 4             1068.0           17           17              9.0
#
#    Procedures Count  SamePhysician  OPD_Flag  PotentialFraud         DOB  \
# 0               0.0            0.0         0               1  1943-01-01
# 1               1.0            1.0         0               0  1943-01-01
# 2               0.0            0.0         0               0  1943-01-01
# 3               1.0            0.0         0               0  1914-03-01
# 4               1.0            0.0         0               0  1938-04-01
#
#           DOD  Gender                       Race  RenalDiseaseIndicator  \
# 0  2009-12-01    Male                      White                      0
# 1  2009-12-01    Male                      White                      0
# 2  2009-12-01    Male                      White                      0
# 3  2009-12-01  Female  Black or African American                      0
# 4  2009-12-01  Female                      White                      1
#
#           State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 0  Pennsylvania     230                   12                   12
# 1  Pennsylvania     230                   12                   12
# 2  Pennsylvania     230                   12                   12
# 3       Alabama     360                   12                   12
# 4          Utah     780                   12                   12
#
#   ChronicCond_Alzheimer ChronicCond_Heartfailure ChronicCond_KidneyDisease  \
# 0                   Yes                       No                       Yes
# 1                   Yes                       No                       Yes
# 2                   Yes                       No                       Yes
# 3                    No                      Yes                       Yes
# 4                    No                      Yes                       Yes
#
#   ChronicCond_Cancer ChronicCond_ObstrPulmonary ChronicCond_Depression  \
# 0                 No                         No                    Yes
# 1                 No                         No                    Yes
# 2                 No                         No                    Yes
# 3                 No                         No                    Yes
# 4                 No                        Yes                    Yes
#
#   ChronicCond_Diabetes ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 0                  Yes                       Yes                       No
# 1                  Yes                       Yes                       No
# 2                  Yes                       Yes                       No
# 3                  Yes                        No                       No
# 4                   No                       Yes                       No
#
#   ChronicCond_rheumatoidarthritis ChronicCond_stroke  \
# 0                             Yes                Yes
# 1                             Yes                Yes
# 2                             Yes                Yes
# 3                             Yes                Yes
# 4                              No                 No
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt  BirthYear   Age  Alive  ChronicDisease_Count
# 0                     70       1943  67.0      0                   7.0
# 1                     70       1943  67.0      0                   7.0
# 2                     70       1943  67.0      0                   7.0
# 3                    320       1914  96.0      0                   6.0
# 4                    100       1938  72.0      0                   5.0

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         0
# BeneID                             0
# ClaimID                            0
# Provider                           0
# InscClaimAmtReimbursed             0
# DeductibleAmtPaid                  0
# ClaimPeriod                        0
# TimeInHptal                        0
# Diagnosis Count                    0
# Procedures Count                   0
# SamePhysician                      0
# OPD_Flag                           0
# PotentialFraud                     0
# DOB                                0
# DOD                                0
# Gender                             0
# Race                               0
# RenalDiseaseIndicator              0
# State                              0
# County                             0
# NoOfMonths_PartACov                0
# NoOfMonths_PartBCov                0
# ChronicCond_Alzheimer              0
# ChronicCond_Heartfailure           0
# ChronicCond_KidneyDisease          0
# ChronicCond_Cancer                 0
# ChronicCond_ObstrPulmonary         0
# ChronicCond_Depression             0
# ChronicCond_Diabetes               0
# ChronicCond_IschemicHeart          0
# ChronicCond_Osteoporasis           0
# ChronicCond_rheumatoidarthritis    0
# ChronicCond_stroke                 0
# IPAnnualReimbursementAmt           0
# IPAnnualDeductibleAmt              0
# OPAnnualReimbursementAmt           0
# OPAnnualDeductibleAmt              0
# BirthYear                          0
# Age                                0
# Alive                              0
# ChronicDisease_Count               0
# dtype: int64

# %%
del df['Unnamed: 0']

# %%
df.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid    ClaimPeriod  \
# count           558211.000000      558211.000000  558211.000000
# mean               997.012133          78.293178       1.727940
# std               3821.534891         273.814592       4.904984
# min                  0.000000          -1.000000       0.000000
# 25%                 40.000000           0.000000       0.000000
# 50%                 80.000000           0.000000       0.000000
# 75%                300.000000           0.000000       0.000000
# max             125000.000000        1068.000000      36.000000
#
#          TimeInHptal  Diagnosis Count  Procedures Count  SamePhysician  \
# count  558211.000000    558211.000000     558211.000000  558211.000000
# mean        0.410762         3.010897          0.053557       0.112248
# std         2.112693         2.448213          0.280534       0.315671
# min         0.000000         0.000000          0.000000       0.000000
# 25%         0.000000         1.000000          0.000000       0.000000
# 50%         0.000000         2.000000          0.000000       0.000000
# 75%         0.000000         4.000000          0.000000       0.000000
# max        35.000000        10.000000          5.000000       1.000000
#
#             OPD_Flag  PotentialFraud  RenalDiseaseIndicator         County  \
# count  558211.000000   558211.000000          558211.000000  558211.000000
# mean        0.927493        0.381211               0.196786     378.588195
# std         0.259325        0.485685               0.397569     265.215531
# min         0.000000        0.000000               0.000000       0.000000
# 25%         1.000000        0.000000               0.000000     150.000000
# 50%         1.000000        0.000000               0.000000     350.000000
# 75%         1.000000        1.000000               0.000000     570.000000
# max         1.000000        1.000000               1.000000     999.000000
#
#        NoOfMonths_PartACov  NoOfMonths_PartBCov  IPAnnualReimbursementAmt  \
# count        558211.000000         558211.00000             558211.000000
# mean             11.931472             11.93877               5227.971466
# std               0.889712              0.78590              11786.274732
# min               0.000000              0.00000              -8000.000000
# 25%              12.000000             12.00000                  0.000000
# 50%              12.000000             12.00000                  0.000000
# 75%              12.000000             12.00000               6000.000000
# max              12.000000             12.00000             161470.000000
#
#        IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  \
# count          558211.000000             558211.000000          558211.000000
# mean              568.756807               2278.225348             649.698745
# std              1179.172616               3881.846386            1002.020811
# min                 0.000000                -70.000000               0.000000
# 25%                 0.000000                460.000000             120.000000
# 50%                 0.000000               1170.000000             340.000000
# 75%              1068.000000               2590.000000             790.000000
# max             38272.000000             102960.000000           13840.000000
#
#            BirthYear            Age     Alive  ChronicDisease_Count
# count  558211.000000  558211.000000  558211.0         558211.000000
# mean     1935.723180      73.769770       0.0              4.498616
# std        13.011761      13.022524       0.0              2.332301
# min      1909.000000      26.000000       0.0              0.000000
# 25%      1927.000000      68.000000       0.0              3.000000
# 50%      1935.000000      75.000000       0.0              5.000000
# 75%      1941.000000      82.000000       0.0              6.000000
# max      1983.000000     101.000000       0.0             11.000000

# %%
df[df['DeductibleAmtPaid']== -1].head()
# Out:
#         BeneID   ClaimID  Provider  InscClaimAmtReimbursed  DeductibleAmtPaid  \
# 20   BENE11057  CLM36789  PRV51393                   13000               -1.0
# 21   BENE11057  CLM38115  PRV51342                   10000               -1.0
# 129  BENE11494  CLM66768  PRV51501                   18000               -1.0
# 159  BENE11592  CLM34790  PRV55262                    6000               -1.0
# 177  BENE11670  CLM37086  PRV52019                     400               -1.0
#
#      ClaimPeriod  TimeInHptal  Diagnosis Count  Procedures Count  \
# 20            35           35              9.0               1.0
# 21             6            6              9.0               0.0
# 129           10           10              9.0               1.0
# 159            5            5              9.0               0.0
# 177            3            3              7.0               0.0
#
#      SamePhysician  OPD_Flag  PotentialFraud         DOB         DOD  Gender  \
# 20             0.0         0               1  1933-02-01  2009-12-01  Female
# 21             0.0         0               0  1933-02-01  2009-12-01  Female
# 129            0.0         0               1  1931-01-01  2009-12-01  Female
# 159            0.0         0               0  1931-04-01  2009-12-01  Female
# 177            0.0         0               1  1920-11-01  2009-12-01  Female
#
#       Race  RenalDiseaseIndicator           State  County  \
# 20   White                      0      California     570
# 21   White                      0      California     570
# 129  White                      0      California     200
# 159  White                      0  North Carolina     440
# 177  White                      0         Florida     590
#
#      NoOfMonths_PartACov  NoOfMonths_PartBCov ChronicCond_Alzheimer  \
# 20                    12                   12                    No
# 21                    12                   12                    No
# 129                   12                   12                   Yes
# 159                   12                   12                   Yes
# 177                   12                   12                    No
#
#     ChronicCond_Heartfailure ChronicCond_KidneyDisease ChronicCond_Cancer  \
# 20                       Yes                       Yes                 No
# 21                       Yes                       Yes                 No
# 129                      Yes                       Yes                Yes
# 159                      Yes                       Yes                 No
# 177                      Yes                       Yes                 No
#
#     ChronicCond_ObstrPulmonary ChronicCond_Depression ChronicCond_Diabetes  \
# 20                         Yes                    Yes                  Yes
# 21                         Yes                    Yes                  Yes
# 129                        Yes                     No                  Yes
# 159                        Yes                    Yes                  Yes
# 177                        Yes                    Yes                  Yes
#
#     ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 20                        Yes                       No
# 21                        Yes                       No
# 129                       Yes                       No
# 159                       Yes                       No
# 177                       Yes                       No
#
#     ChronicCond_rheumatoidarthritis ChronicCond_stroke  \
# 20                               No                 No
# 21                               No                 No
# 129                             Yes                 No
# 159                             Yes                 No
# 177                             Yes                 No
#
#      IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 20                      41080                   2136
# 21                      41080                   2136
# 129                     29500                   3204
# 159                     60000                  10204
# 177                     76460                   4272
#
#      OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  BirthYear   Age  Alive  \
# 20                        200                     50       1933  77.0      0
# 21                        200                     50       1933  77.0      0
# 129                      3510                     60       1931  79.0      0
# 159                       310                     30       1931  79.0      0
# 177                      3110                    470       1920  89.0      0
#
#      ChronicDisease_Count
# 20                    6.0
# 21                    6.0
# 129                   8.0
# 159                   8.0
# 177                   7.0

# %%
df['DeductibleAmtPaid'] = df['DeductibleAmtPaid'].replace(-1,0)

# %%
df.head()
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed  DeductibleAmtPaid  \
# 0  BENE11001  CLM46614  PRV55912                   26000             1068.0
# 1  BENE11001  CLM66048  PRV55907                    5000             1068.0
# 2  BENE11001  CLM68358  PRV56046                    5000             1068.0
# 3  BENE11011  CLM38412  PRV52405                    5000             1068.0
# 4  BENE11014  CLM63689  PRV56614                   10000             1068.0
#
#    ClaimPeriod  TimeInHptal  Diagnosis Count  Procedures Count  SamePhysician  \
# 0            6            6              9.0               0.0            0.0
# 1            2            2              3.0               1.0            1.0
# 2            3            3              6.0               0.0            0.0
# 3            8            8              9.0               1.0            0.0
# 4           17           17              9.0               1.0            0.0
#
#    OPD_Flag  PotentialFraud         DOB         DOD  Gender  \
# 0         0               1  1943-01-01  2009-12-01    Male
# 1         0               0  1943-01-01  2009-12-01    Male
# 2         0               0  1943-01-01  2009-12-01    Male
# 3         0               0  1914-03-01  2009-12-01  Female
# 4         0               0  1938-04-01  2009-12-01  Female
#
#                         Race  RenalDiseaseIndicator         State  County  \
# 0                      White                      0  Pennsylvania     230
# 1                      White                      0  Pennsylvania     230
# 2                      White                      0  Pennsylvania     230
# 3  Black or African American                      0       Alabama     360
# 4                      White                      1          Utah     780
#
#    NoOfMonths_PartACov  NoOfMonths_PartBCov ChronicCond_Alzheimer  \
# 0                   12                   12                   Yes
# 1                   12                   12                   Yes
# 2                   12                   12                   Yes
# 3                   12                   12                    No
# 4                   12                   12                    No
#
#   ChronicCond_Heartfailure ChronicCond_KidneyDisease ChronicCond_Cancer  \
# 0                       No                       Yes                 No
# 1                       No                       Yes                 No
# 2                       No                       Yes                 No
# 3                      Yes                       Yes                 No
# 4                      Yes                       Yes                 No
#
#   ChronicCond_ObstrPulmonary ChronicCond_Depression ChronicCond_Diabetes  \
# 0                         No                    Yes                  Yes
# 1                         No                    Yes                  Yes
# 2                         No                    Yes                  Yes
# 3                         No                    Yes                  Yes
# 4                        Yes                    Yes                   No
#
#   ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 0                       Yes                       No
# 1                       Yes                       No
# 2                       Yes                       No
# 3                        No                       No
# 4                       Yes                       No
#
#   ChronicCond_rheumatoidarthritis ChronicCond_stroke  \
# 0                             Yes                Yes
# 1                             Yes                Yes
# 2                             Yes                Yes
# 3                             Yes                Yes
# 4                              No                 No
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt  BirthYear   Age  Alive  ChronicDisease_Count
# 0                     70       1943  67.0      0                   7.0
# 1                     70       1943  67.0      0                   7.0
# 2                     70       1943  67.0      0                   7.0
# 3                    320       1914  96.0      0                   6.0
# 4                    100       1938  72.0      0                   5.0

# %%
df.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid    ClaimPeriod  \
# count           558211.000000      558211.000000  558211.000000
# mean               997.012133          78.294788       1.727940
# std               3821.534891         273.814128       4.904984
# min                  0.000000           0.000000       0.000000
# 25%                 40.000000           0.000000       0.000000
# 50%                 80.000000           0.000000       0.000000
# 75%                300.000000           0.000000       0.000000
# max             125000.000000        1068.000000      36.000000
#
#          TimeInHptal  Diagnosis Count  Procedures Count  SamePhysician  \
# count  558211.000000    558211.000000     558211.000000  558211.000000
# mean        0.410762         3.010897          0.053557       0.112248
# std         2.112693         2.448213          0.280534       0.315671
# min         0.000000         0.000000          0.000000       0.000000
# 25%         0.000000         1.000000          0.000000       0.000000
# 50%         0.000000         2.000000          0.000000       0.000000
# 75%         0.000000         4.000000          0.000000       0.000000
# max        35.000000        10.000000          5.000000       1.000000
#
#             OPD_Flag  PotentialFraud  RenalDiseaseIndicator         County  \
# count  558211.000000   558211.000000          558211.000000  558211.000000
# mean        0.927493        0.381211               0.196786     378.588195
# std         0.259325        0.485685               0.397569     265.215531
# min         0.000000        0.000000               0.000000       0.000000
# 25%         1.000000        0.000000               0.000000     150.000000
# 50%         1.000000        0.000000               0.000000     350.000000
# 75%         1.000000        1.000000               0.000000     570.000000
# max         1.000000        1.000000               1.000000     999.000000
#
#        NoOfMonths_PartACov  NoOfMonths_PartBCov  IPAnnualReimbursementAmt  \
# count        558211.000000         558211.00000             558211.000000
# mean             11.931472             11.93877               5227.971466
# std               0.889712              0.78590              11786.274732
# min               0.000000              0.00000              -8000.000000
# 25%              12.000000             12.00000                  0.000000
# 50%              12.000000             12.00000                  0.000000
# 75%              12.000000             12.00000               6000.000000
# max              12.000000             12.00000             161470.000000
#
#        IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  \
# count          558211.000000             558211.000000          558211.000000
# mean              568.756807               2278.225348             649.698745
# std              1179.172616               3881.846386            1002.020811
# min                 0.000000                -70.000000               0.000000
# 25%                 0.000000                460.000000             120.000000
# 50%                 0.000000               1170.000000             340.000000
# 75%              1068.000000               2590.000000             790.000000
# max             38272.000000             102960.000000           13840.000000
#
#            BirthYear            Age     Alive  ChronicDisease_Count
# count  558211.000000  558211.000000  558211.0         558211.000000
# mean     1935.723180      73.769770       0.0              4.498616
# std        13.011761      13.022524       0.0              2.332301
# min      1909.000000      26.000000       0.0              0.000000
# 25%      1927.000000      68.000000       0.0              3.000000
# 50%      1935.000000      75.000000       0.0              5.000000
# 75%      1941.000000      82.000000       0.0              6.000000
# max      1983.000000     101.000000       0.0             11.000000

# %%
df['OPD_Flag'] = df['OPD_Flag'].astype('object')
df['SamePhysician'] = df['SamePhysician'].astype('object')
df['RenalDiseaseIndicator'] = df['RenalDiseaseIndicator'].astype('object')

# %%
df.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid    ClaimPeriod  \
# count           558211.000000      558211.000000  558211.000000
# mean               997.012133          78.294788       1.727940
# std               3821.534891         273.814128       4.904984
# min                  0.000000           0.000000       0.000000
# 25%                 40.000000           0.000000       0.000000
# 50%                 80.000000           0.000000       0.000000
# 75%                300.000000           0.000000       0.000000
# max             125000.000000        1068.000000      36.000000
#
#          TimeInHptal  Diagnosis Count  Procedures Count  PotentialFraud  \
# count  558211.000000    558211.000000     558211.000000   558211.000000
# mean        0.410762         3.010897          0.053557        0.381211
# std         2.112693         2.448213          0.280534        0.485685
# min         0.000000         0.000000          0.000000        0.000000
# 25%         0.000000         1.000000          0.000000        0.000000
# 50%         0.000000         2.000000          0.000000        0.000000
# 75%         0.000000         4.000000          0.000000        1.000000
# max        35.000000        10.000000          5.000000        1.000000
#
#               County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# count  558211.000000        558211.000000         558211.00000
# mean      378.588195            11.931472             11.93877
# std       265.215531             0.889712              0.78590
# min         0.000000             0.000000              0.00000
# 25%       150.000000            12.000000             12.00000
# 50%       350.000000            12.000000             12.00000
# 75%       570.000000            12.000000             12.00000
# max       999.000000            12.000000             12.00000
#
#        IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# count             558211.000000          558211.000000
# mean                5227.971466             568.756807
# std                11786.274732            1179.172616
# min                -8000.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.000000               0.000000
# 75%                 6000.000000            1068.000000
# max               161470.000000           38272.000000
#
#        OPAnnualReimbursementAmt  OPAnnualDeductibleAmt      BirthYear  \
# count             558211.000000          558211.000000  558211.000000
# mean                2278.225348             649.698745    1935.723180
# std                 3881.846386            1002.020811      13.011761
# min                  -70.000000               0.000000    1909.000000
# 25%                  460.000000             120.000000    1927.000000
# 50%                 1170.000000             340.000000    1935.000000
# 75%                 2590.000000             790.000000    1941.000000
# max               102960.000000           13840.000000    1983.000000
#
#                  Age     Alive  ChronicDisease_Count
# count  558211.000000  558211.0         558211.000000
# mean       73.769770       0.0              4.498616
# std        13.022524       0.0              2.332301
# min        26.000000       0.0              0.000000
# 25%        68.000000       0.0              3.000000
# 50%        75.000000       0.0              5.000000
# 75%        82.000000       0.0              6.000000
# max       101.000000       0.0             11.000000

# %%
df[df['IPAnnualReimbursementAmt']<0].shape
# Out:
# (57, 40)

# %%
df[df['OPAnnualReimbursementAmt']<0].shape
# Out:
# (16, 40)

# %%
df[(df['IPAnnualReimbursementAmt']<0) & (df['OPAnnualReimbursementAmt']<0)].shape
# Out:
# (0, 40)

# %%
df = df[df['IPAnnualReimbursementAmt']>=0].reset_index(drop=True)
df = df[df['OPAnnualReimbursementAmt']>=0].reset_index(drop=True)
df.shape
# Out:
# (558138, 40)

# %%
df.tail()
# Out:
#             BeneID    ClaimID  Provider  InscClaimAmtReimbursed  \
# 558133  BENE159198  CLM510792  PRV53699                     800
# 558134  BENE159198  CLM551294  PRV53702                     400
# 558135  BENE159198  CLM596444  PRV53676                      60
# 558136  BENE159198  CLM636992  PRV53689                      70
# 558137  BENE159198  CLM686139  PRV53689                      80
#
#         DeductibleAmtPaid  ClaimPeriod  TimeInHptal  Diagnosis Count  \
# 558133                0.0            0            0              3.0
# 558134                0.0            0            0              3.0
# 558135                0.0            0            0              2.0
# 558136                0.0            0            0              0.0
# 558137                0.0            1            0              8.0
#
#         Procedures Count SamePhysician OPD_Flag  PotentialFraud         DOB  \
# 558133               0.0           1.0        1               0  1952-04-01
# 558134               0.0           0.0        1               0  1952-04-01
# 558135               0.0           0.0        1               0  1952-04-01
# 558136               0.0           0.0        1               0  1952-04-01
# 558137               0.0           0.0        1               0  1952-04-01
#
#                DOD  Gender   Race RenalDiseaseIndicator     State  County  \
# 558133  2009-12-01  Female  White                     0  Maryland      20
# 558134  2009-12-01  Female  White                     0  Maryland      20
# 558135  2009-12-01  Female  White                     0  Maryland      20
# 558136  2009-12-01  Female  White                     0  Maryland      20
# 558137  2009-12-01  Female  White                     0  Maryland      20
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov ChronicCond_Alzheimer  \
# 558133                   12                   12                   Yes
# 558134                   12                   12                   Yes
# 558135                   12                   12                   Yes
# 558136                   12                   12                   Yes
# 558137                   12                   12                   Yes
#
#        ChronicCond_Heartfailure ChronicCond_KidneyDisease ChronicCond_Cancer  \
# 558133                      Yes                        No                 No
# 558134                      Yes                        No                 No
# 558135                      Yes                        No                 No
# 558136                      Yes                        No                 No
# 558137                      Yes                        No                 No
#
#        ChronicCond_ObstrPulmonary ChronicCond_Depression ChronicCond_Diabetes  \
# 558133                         No                    Yes                  Yes
# 558134                         No                    Yes                  Yes
# 558135                         No                    Yes                  Yes
# 558136                         No                    Yes                  Yes
# 558137                         No                    Yes                  Yes
#
#        ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 558133                        No                       No
# 558134                        No                       No
# 558135                        No                       No
# 558136                        No                       No
# 558137                        No                       No
#
#        ChronicCond_rheumatoidarthritis ChronicCond_stroke  \
# 558133                             Yes                 No
# 558134                             Yes                 No
# 558135                             Yes                 No
# 558136                             Yes                 No
# 558137                             Yes                 No
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 558133                         0                      0
# 558134                         0                      0
# 558135                         0                      0
# 558136                         0                      0
# 558137                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  BirthYear   Age  \
# 558133                      5470                   1870       1952  58.0
# 558134                      5470                   1870       1952  58.0
# 558135                      5470                   1870       1952  58.0
# 558136                      5470                   1870       1952  58.0
# 558137                      5470                   1870       1952  58.0
#
#         Alive  ChronicDisease_Count
# 558133      0                   5.0
# 558134      0                   5.0
# 558135      0                   5.0
# 558136      0                   5.0
# 558137      0                   5.0

# %%
df.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid    ClaimPeriod  \
# count           558138.000000      558138.000000  558138.000000
# mean               996.806184          78.275842       1.727711
# std               3820.614730         273.782870       4.904651
# min                  0.000000           0.000000       0.000000
# 25%                 40.000000           0.000000       0.000000
# 50%                 80.000000           0.000000       0.000000
# 75%                300.000000           0.000000       0.000000
# max             125000.000000        1068.000000      36.000000
#
#          TimeInHptal  Diagnosis Count  Procedures Count  PotentialFraud  \
# count  558138.000000    558138.000000     558138.000000   558138.000000
# mean        0.410630         3.010793          0.053537        0.381212
# std         2.112183         2.448085          0.280484        0.485685
# min         0.000000         0.000000          0.000000        0.000000
# 25%         0.000000         1.000000          0.000000        0.000000
# 50%         0.000000         2.000000          0.000000        0.000000
# 75%         0.000000         4.000000          0.000000        1.000000
# max        35.000000        10.000000          5.000000        1.000000
#
#               County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# count  558138.000000        558138.000000        558138.000000
# mean      378.587666            11.931463            11.938762
# std       265.210830             0.889769             0.785951
# min         0.000000             0.000000             0.000000
# 25%       150.000000            12.000000            12.000000
# 50%       350.000000            12.000000            12.000000
# 75%       570.000000            12.000000            12.000000
# max       999.000000            12.000000            12.000000
#
#        IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# count             558138.000000          558138.000000
# mean                5228.095847             568.674654
# std                11785.791749            1179.216729
# min                    0.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.000000               0.000000
# 75%                 6000.000000            1068.000000
# max               161470.000000           38272.000000
#
#        OPAnnualReimbursementAmt  OPAnnualDeductibleAmt      BirthYear  \
# count             558138.000000          558138.000000  558138.000000
# mean                2278.394824             649.732926    1935.723183
# std                 3882.045712            1002.070824      13.011398
# min                    0.000000               0.000000    1909.000000
# 25%                  460.000000             120.000000    1927.000000
# 50%                 1170.000000             340.000000    1935.000000
# 75%                 2590.000000             790.000000    1941.000000
# max               102960.000000           13840.000000    1983.000000
#
#                  Age     Alive  ChronicDisease_Count
# count  558138.000000  558138.0         558138.000000
# mean       73.769772       0.0              4.498626
# std        13.022134       0.0              2.332332
# min        26.000000       0.0              0.000000
# 25%        68.000000       0.0              3.000000
# 50%        75.000000       0.0              5.000000
# 75%        82.000000       0.0              6.000000
# max       101.000000       0.0             11.000000

# %%
df[df['InscClaimAmtReimbursed']>100000].head()
# Out:
#          BeneID   ClaimID  Provider  InscClaimAmtReimbursed  \
# 10    BENE11034  CLM57949  PRV55193                  102000
# 708   BENE13669  CLM67392  PRV55172                  125000
# 832   BENE14036  CLM54264  PRV54942                  124000
# 3075  BENE22137  CLM59789  PRV52077                  112000
# 3998  BENE25318  CLM34029  PRV51399                  103000
#
#       DeductibleAmtPaid  ClaimPeriod  TimeInHptal  Diagnosis Count  \
# 10               1068.0            8            8              9.0
# 708              1068.0           35           35              7.0
# 832                 0.0           21           21              9.0
# 3075             1068.0           12           12              8.0
# 3998             1068.0            7            7             10.0
#
#       Procedures Count SamePhysician OPD_Flag  PotentialFraud         DOB  \
# 10                 1.0           0.0        0               1  1946-03-01
# 708                2.0           0.0        0               1  1941-05-01
# 832                1.0           0.0        0               1  1917-07-01
# 3075               0.0           0.0        0               1  1927-01-01
# 3998               1.0           0.0        0               1  1938-09-01
#
#              DOD  Gender                       Race RenalDiseaseIndicator  \
# 10    2009-12-01  Female                      White                     0
# 708   2009-12-01    Male  Black or African American                     0
# 832   2009-12-01  Female  Black or African American                     0
# 3075  2009-12-01    Male                      White                     1
# 3998  2009-12-01    Male                      White                     0
#
#                State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 10    North Carolina     760                   12                   12
# 708   North Carolina     730                   12                   12
# 832         New York     770                   12                   12
# 3075         Florida     510                   12                   12
# 3998      California     370                   12                   12
#
#      ChronicCond_Alzheimer ChronicCond_Heartfailure ChronicCond_KidneyDisease  \
# 10                     Yes                      Yes                       Yes
# 708                     No                      Yes                        No
# 832                     No                      Yes                       Yes
# 3075                   Yes                      Yes                       Yes
# 3998                    No                      Yes                        No
#
#      ChronicCond_Cancer ChronicCond_ObstrPulmonary ChronicCond_Depression  \
# 10                   No                        Yes                    Yes
# 708                  No                         No                     No
# 832                  No                        Yes                    Yes
# 3075                Yes                        Yes                    Yes
# 3998                 No                         No                     No
#
#      ChronicCond_Diabetes ChronicCond_IschemicHeart ChronicCond_Osteoporasis  \
# 10                    Yes                       Yes                       No
# 708                    No                       Yes                       No
# 832                   Yes                       Yes                       No
# 3075                  Yes                       Yes                      Yes
# 3998                   No                       Yes                       No
#
#      ChronicCond_rheumatoidarthritis ChronicCond_stroke  \
# 10                               Yes                Yes
# 708                               No                 No
# 832                              Yes                 No
# 3075                              No                 No
# 3998                              No                Yes
#
#       IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 10                      131140                   2136
# 708                     139400                   1068
# 832                     148580                   2136
# 3075                    153580                   5640
# 3998                    103490                   1068
#
#       OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  BirthYear   Age  Alive  \
# 10                        1650                     80       1946  64.0      0
# 708                     102960                    956       1941  69.0      0
# 832                       4200                    810       1917  92.0      0
# 3075                      5890                   2070       1927  83.0      0
# 3998                     85160                   1476       1938  71.0      0
#
#       ChronicDisease_Count
# 10                     9.0
# 708                    2.0
# 832                    7.0
# 3075                   9.0
# 3998                   3.0

# %% [markdown]
# ### Columns to treat that contains outliers
# 1. InscClaimAmtReimbursed
# 2. IPAnnualReimbursement
# 3. OPAnnualReimbursement
# 4. IPAnnualDeductibleAmt
# 5. OPAnnualDeductibleAmt

# %% [markdown]
# ### Outlier Treatment

# %%
df.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid    ClaimPeriod  \
# count           558138.000000      558138.000000  558138.000000
# mean               996.806184          78.275842       1.727711
# std               3820.614730         273.782870       4.904651
# min                  0.000000           0.000000       0.000000
# 25%                 40.000000           0.000000       0.000000
# 50%                 80.000000           0.000000       0.000000
# 75%                300.000000           0.000000       0.000000
# max             125000.000000        1068.000000      36.000000
#
#          TimeInHptal  Diagnosis Count  Procedures Count  PotentialFraud  \
# count  558138.000000    558138.000000     558138.000000   558138.000000
# mean        0.410630         3.010793          0.053537        0.381212
# std         2.112183         2.448085          0.280484        0.485685
# min         0.000000         0.000000          0.000000        0.000000
# 25%         0.000000         1.000000          0.000000        0.000000
# 50%         0.000000         2.000000          0.000000        0.000000
# 75%         0.000000         4.000000          0.000000        1.000000
# max        35.000000        10.000000          5.000000        1.000000
#
#               County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# count  558138.000000        558138.000000        558138.000000
# mean      378.587666            11.931463            11.938762
# std       265.210830             0.889769             0.785951
# min         0.000000             0.000000             0.000000
# 25%       150.000000            12.000000            12.000000
# 50%       350.000000            12.000000            12.000000
# 75%       570.000000            12.000000            12.000000
# max       999.000000            12.000000            12.000000
#
#        IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# count             558138.000000          558138.000000
# mean                5228.095847             568.674654
# std                11785.791749            1179.216729
# min                    0.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.000000               0.000000
# 75%                 6000.000000            1068.000000
# max               161470.000000           38272.000000
#
#        OPAnnualReimbursementAmt  OPAnnualDeductibleAmt      BirthYear  \
# count             558138.000000          558138.000000  558138.000000
# mean                2278.394824             649.732926    1935.723183
# std                 3882.045712            1002.070824      13.011398
# min                    0.000000               0.000000    1909.000000
# 25%                  460.000000             120.000000    1927.000000
# 50%                 1170.000000             340.000000    1935.000000
# 75%                 2590.000000             790.000000    1941.000000
# max               102960.000000           13840.000000    1983.000000
#
#                  Age     Alive  ChronicDisease_Count
# count  558138.000000  558138.0         558138.000000
# mean       73.769772       0.0              4.498626
# std        13.022134       0.0              2.332332
# min        26.000000       0.0              0.000000
# 25%        68.000000       0.0              3.000000
# 50%        75.000000       0.0              5.000000
# 75%        82.000000       0.0              6.000000
# max       101.000000       0.0             11.000000

# %%
df[df['DeductibleAmtPaid']>0].shape
# Out:
# (60592, 40)

# %%
def treat_outliers(df, columns):
   
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR\
        # Cap outliers
        df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
        df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])
    return df

# %%
df = treat_outliers(df, ['InscClaimAmtReimbursed', 'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt'])

# %%
df.describe()
# Out:
#        InscClaimAmtReimbursed  DeductibleAmtPaid    ClaimPeriod  \
# count           558138.000000      558138.000000  558138.000000
# mean               214.277258          78.275842       1.727711
# std                248.572190         273.782870       4.904651
# min                  0.000000           0.000000       0.000000
# 25%                 40.000000           0.000000       0.000000
# 50%                 80.000000           0.000000       0.000000
# 75%                300.000000           0.000000       0.000000
# max                690.000000        1068.000000      36.000000
#
#          TimeInHptal  Diagnosis Count  Procedures Count  PotentialFraud  \
# count  558138.000000    558138.000000     558138.000000   558138.000000
# mean        0.410630         3.010793          0.053537        0.381212
# std         2.112183         2.448085          0.280484        0.485685
# min         0.000000         0.000000          0.000000        0.000000
# 25%         0.000000         1.000000          0.000000        0.000000
# 50%         0.000000         2.000000          0.000000        0.000000
# 75%         0.000000         4.000000          0.000000        1.000000
# max        35.000000        10.000000          5.000000        1.000000
#
#               County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# count  558138.000000        558138.000000        558138.000000
# mean      378.587666            11.931463            11.938762
# std       265.210830             0.889769             0.785951
# min         0.000000             0.000000             0.000000
# 25%       150.000000            12.000000            12.000000
# 50%       350.000000            12.000000            12.000000
# 75%       570.000000            12.000000            12.000000
# max       999.000000            12.000000            12.000000
#
#        IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# count             558138.000000          558138.000000
# mean                3346.451523             502.191917
# std                 5434.170231             785.740737
# min                    0.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.000000               0.000000
# 75%                 6000.000000            1068.000000
# max                15000.000000            2670.000000
#
#        OPAnnualReimbursementAmt  OPAnnualDeductibleAmt      BirthYear  \
# count             558138.000000          558138.000000  558138.000000
# mean                1775.557649             533.814659    1935.723183
# std                 1692.759775             526.272005      13.011398
# min                    0.000000               0.000000    1909.000000
# 25%                  460.000000             120.000000    1927.000000
# 50%                 1170.000000             340.000000    1935.000000
# 75%                 2590.000000             790.000000    1941.000000
# max                 5785.000000            1795.000000    1983.000000
#
#                  Age     Alive  ChronicDisease_Count
# count  558138.000000  558138.0         558138.000000
# mean       73.769772       0.0              4.498626
# std        13.022134       0.0              2.332332
# min        26.000000       0.0              0.000000
# 25%        68.000000       0.0              3.000000
# 50%        75.000000       0.0              5.000000
# 75%        82.000000       0.0              6.000000
# max       101.000000       0.0             11.000000

# %%
df.drop(columns={'DOB', 'DOD', 'Alive', 'State', 'County'}, inplace=True)

# %%
df.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'DeductibleAmtPaid', 'ClaimPeriod', 'TimeInHptal', 'Diagnosis Count',
#        'Procedures Count', 'SamePhysician', 'OPD_Flag', 'PotentialFraud',
#        'Gender', 'Race', 'RenalDiseaseIndicator', 'NoOfMonths_PartACov',
#        'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
#        'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
#        'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'BirthYear', 'Age',
#        'ChronicDisease_Count'],
#       dtype='object')

# %% [markdown]
# ### Categorical Columns Overview

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'SamePhysician', 'OPD_Flag', 'Gender',
#        'Race', 'RenalDiseaseIndicator', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke'],
#       dtype='object')

# %%
df['Race'].value_counts()
# Out:
# Race
# White                        470982
# Black or African American     55628
# Other                         19708
# Hispanic                      11820
# Name: count, dtype: int64

# %%
df['RenalDiseaseIndicator'] = df['RenalDiseaseIndicator'].replace({0: 'No', 1: 'Yes'})
df['OPD_Flag'] = df['OPD_Flag'].replace({0: 'No', 1: 'Yes'})
df['SamePhysician'] = df['SamePhysician'].astype(int).replace({0: 'No', 1: 'Yes'})

# %% [markdown]
# ### Base Model

# %%
df['ClaimID'].nunique()
# Out:
# 558138

# %%
del df['BeneID']

# %%
df.shape
# Out:
# (558138, 34)

# %% [markdown]
# #### One-hot encoding

# %%
pd.get_dummies(df, columns= cat_cols, drop_first=True)
# Out:
#           ClaimID  Provider  InscClaimAmtReimbursed  DeductibleAmtPaid  \
# 0        CLM46614  PRV55912                   690.0             1068.0
# 1        CLM66048  PRV55907                   690.0             1068.0
# 2        CLM68358  PRV56046                   690.0             1068.0
# 3        CLM38412  PRV52405                   690.0             1068.0
# 4        CLM63689  PRV56614                   690.0             1068.0
# ...           ...       ...                     ...                ...
# 558133  CLM510792  PRV53699                   690.0                0.0
# 558134  CLM551294  PRV53702                   400.0                0.0
# 558135  CLM596444  PRV53676                    60.0                0.0
# 558136  CLM636992  PRV53689                    70.0                0.0
# 558137  CLM686139  PRV53689                    80.0                0.0
#
#         ClaimPeriod  TimeInHptal  Diagnosis Count  Procedures Count  \
# 0                 6            6              9.0               0.0
# 1                 2            2              3.0               1.0
# 2                 3            3              6.0               0.0
# 3                 8            8              9.0               1.0
# 4                17           17              9.0               1.0
# ...             ...          ...              ...               ...
# 558133            0            0              3.0               0.0
# 558134            0            0              3.0               0.0
# 558135            0            0              2.0               0.0
# 558136            0            0              0.0               0.0
# 558137            1            0              8.0               0.0
#
#         PotentialFraud  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 0                    1                   12                   12
# 1                    0                   12                   12
# 2                    0                   12                   12
# 3                    0                   12                   12
# 4                    0                   12                   12
# ...                ...                  ...                  ...
# 558133               0                   12                   12
# 558134               0                   12                   12
# 558135               0                   12                   12
# 558136               0                   12                   12
# 558137               0                   12                   12
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                        15000.0                 2670.0
# 1                        15000.0                 2670.0
# 2                        15000.0                 2670.0
# 3                         5000.0                 1068.0
# 4                        15000.0                 2136.0
# ...                          ...                    ...
# 558133                       0.0                    0.0
# 558134                       0.0                    0.0
# 558135                       0.0                    0.0
# 558136                       0.0                    0.0
# 558137                       0.0                    0.0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  BirthYear   Age  \
# 0                           60.0                   70.0       1943  67.0
# 1                           60.0                   70.0       1943  67.0
# 2                           60.0                   70.0       1943  67.0
# 3                          250.0                  320.0       1914  96.0
# 4                          120.0                  100.0       1938  72.0
# ...                          ...                    ...        ...   ...
# 558133                    5470.0                 1795.0       1952  58.0
# 558134                    5470.0                 1795.0       1952  58.0
# 558135                    5470.0                 1795.0       1952  58.0
# 558136                    5470.0                 1795.0       1952  58.0
# 558137                    5470.0                 1795.0       1952  58.0
#
#         ChronicDisease_Count  SamePhysician_Yes  OPD_Flag_Yes  Gender_Male  \
# 0                        7.0              False         False         True
# 1                        7.0               True         False         True
# 2                        7.0              False         False         True
# 3                        6.0              False         False        False
# 4                        5.0              False         False        False
# ...                      ...                ...           ...          ...
# 558133                   5.0               True          True        False
# 558134                   5.0              False          True        False
# 558135                   5.0              False          True        False
# 558136                   5.0              False          True        False
# 558137                   5.0              False          True        False
#
#         Race_Hispanic  Race_Other  Race_White  RenalDiseaseIndicator_Yes  \
# 0               False       False        True                      False
# 1               False       False        True                      False
# 2               False       False        True                      False
# 3               False       False       False                      False
# 4               False       False        True                       True
# ...               ...         ...         ...                        ...
# 558133          False       False        True                      False
# 558134          False       False        True                      False
# 558135          False       False        True                      False
# 558136          False       False        True                      False
# 558137          False       False        True                      False
#
#         ChronicCond_Alzheimer_Yes  ChronicCond_Heartfailure_Yes  \
# 0                            True                         False
# 1                            True                         False
# 2                            True                         False
# 3                           False                          True
# 4                           False                          True
# ...                           ...                           ...
# 558133                       True                          True
# 558134                       True                          True
# 558135                       True                          True
# 558136                       True                          True
# 558137                       True                          True
#
#         ChronicCond_KidneyDisease_Yes  ChronicCond_Cancer_Yes  \
# 0                                True                   False
# 1                                True                   False
# 2                                True                   False
# 3                                True                   False
# 4                                True                   False
# ...                               ...                     ...
# 558133                          False                   False
# 558134                          False                   False
# 558135                          False                   False
# 558136                          False                   False
# 558137                          False                   False
#
#         ChronicCond_ObstrPulmonary_Yes  ChronicCond_Depression_Yes  \
# 0                                False                        True
# 1                                False                        True
# 2                                False                        True
# 3                                False                        True
# 4                                 True                        True
# ...                                ...                         ...
# 558133                           False                        True
# 558134                           False                        True
# 558135                           False                        True
# 558136                           False                        True
# 558137                           False                        True
#
#         ChronicCond_Diabetes_Yes  ChronicCond_IschemicHeart_Yes  \
# 0                           True                           True
# 1                           True                           True
# 2                           True                           True
# 3                           True                          False
# 4                          False                           True
# ...                          ...                            ...
# 558133                      True                          False
# 558134                      True                          False
# 558135                      True                          False
# 558136                      True                          False
# 558137                      True                          False
#
#         ChronicCond_Osteoporasis_Yes  ChronicCond_rheumatoidarthritis_Yes  \
# 0                              False                                 True
# 1                              False                                 True
# 2                              False                                 True
# 3                              False                                 True
# 4                              False                                False
# ...                              ...                                  ...
# 558133                         False                                 True
# 558134                         False                                 True
# 558135                         False                                 True
# 558136                         False                                 True
# 558137                         False                                 True
#
#         ChronicCond_stroke_Yes
# 0                         True
# 1                         True
# 2                         True
# 3                         True
# 4                        False
# ...                        ...
# 558133                   False
# 558134                   False
# 558135                   False
# 558136                   False
# 558137                   False
#
# [558138 rows x 36 columns]

# %%
cat_cols = ['SamePhysician', 'OPD_Flag', 'Gender',
       'Race', 'RenalDiseaseIndicator', 'ChronicCond_Alzheimer',
       'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
       'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
       'ChronicCond_Depression', 'ChronicCond_Diabetes',
       'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
       'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke']

data_encoded = pd.get_dummies(df, columns= cat_cols, drop_first=True)
data_encoded.shape
# Out:
# (558138, 36)

# %%
X = data_encoded.drop(columns='PotentialFraud')
y = data_encoded['PotentialFraud']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42, stratify=y)
print('X_train:', X_train.shape)
print('X_test:', X_test.shape)
print('y_train:', y_train.shape)
print('y_test:', y_test.shape)
# Out:
# X_train: (390696, 35)
# X_test: (167442, 35)
# y_train: (390696,)
# y_test: (167442,)

# %%
y_train.value_counts(normalize=True), y_test.value_counts(normalize=True)
# Out:
# (PotentialFraud
#  0    0.618788
#  1    0.381212
#  Name: proportion, dtype: float64,
#  PotentialFraud
#  0    0.618787
#  1    0.381213
#  Name: proportion, dtype: float64)

# %%
lr_model = LogisticRegression(class_weight='balanced', random_state=42)
lr_model.fit(X_train.drop(['ClaimID', 'Provider'], axis=1), y_train)
# Out:
# d:\Naira Documents\Git_projects\MediClaim_Fraud_Detection\.venv\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced', random_state=42)

# %%
import mlflow
import mlflow.sklearn
 
try:
    # Set MLflow Tracking URI using SQL Server and Windows Authentication
    mlflow.set_tracking_uri("mssql+pyodbc://DESKTOP-KI17L18\SQLEXPRESS/Medicare_claim_SMA?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes")
 
    # Name the experiment
    mlflow.set_experiment("MedicareClaim_Fraud_Detection")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 import mlflow
#       2 import mlflow.sklearn
#       4 try:
#       5     # Set MLflow Tracking URI using SQL Server and Windows Authentication
#
# ModuleNotFoundError: No module named 'mlflow'

# %% [markdown]
# Will Consider Recall because we need to reduce false Positive cases

# %% [markdown]
# ###
